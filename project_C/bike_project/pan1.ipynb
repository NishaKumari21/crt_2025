# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
df=pd.read_csv('Used_Bikes.csv')
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df=pd.read_csv(r"C:\Users\HP\Desktop\data_sci_upflairs\PANDAS\Used_Bikes.csv")
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df.head(10)
# by dafault 5
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# 5                          Yamaha FZs 150cc   53499.0      Delhi     25000.0
# 6             Honda CB Hornet 160R  ABS DLX   85000.0      Delhi      8200.0
# 7       Hero Splendor Plus Self Alloy 100cc   45000.0      Delhi     12645.0
# 8         Royal Enfield Thunderbird X 350cc  145000.0  Bangalore      9190.0
# 9  Royal Enfield Classic Desert Storm 500cc   88000.0      Delhi     19000.0
#
#           owner  age  power          brand
# 0   First Owner  3.0  110.0            TVS
# ...

# %%
df.tail()
# Out:
#                        bike_name    price    city  kms_driven        owner  \
# 32643     Hero Passion Pro 100cc  39000.0   Delhi     22000.0  First Owner
# 32644       TVS Apache RTR 180cc  30000.0  Karnal      6639.0  First Owner
# 32645   Bajaj Avenger Street 220  60000.0   Delhi     20373.0  First Owner
# 32646  Hero Super Splendor 125cc  15600.0  Jaipur     84186.0  First Owner
# 32647         Bajaj Pulsar 150cc  22000.0    Pune     60857.0  First Owner
#
#         age  power  brand
# 32643   4.0  100.0   Hero
# 32644   9.0  180.0    TVS
# 32645   6.0  220.0  Bajaj
# 32646  16.0  125.0   Hero
# 32647  13.0  150.0  Bajaj

# %%
df.tail(10)
# Out:
#                          bike_name     price         city  kms_driven  \
# 32638        Yamaha Fazer 25 250cc  123000.0       Kadapa     14500.0
# 32639  Royal Enfield Classic 350cc   95500.0        Delhi     18000.0
# 32640       Hero Passion Pro 100cc   32000.0        Delhi     12000.0
# 32641          Bajaj Avenger 220cc   41000.0        Delhi     20245.0
# 32642           Hero Passion 100cc   15000.0  Perumbavoor     35000.0
# 32643       Hero Passion Pro 100cc   39000.0        Delhi     22000.0
# 32644         TVS Apache RTR 180cc   30000.0       Karnal      6639.0
# 32645     Bajaj Avenger Street 220   60000.0        Delhi     20373.0
# 32646    Hero Super Splendor 125cc   15600.0       Jaipur     84186.0
# 32647           Bajaj Pulsar 150cc   22000.0         Pune     60857.0
#
#               owner   age  power          brand
# 32638   First Owner   4.0  250.0         Yamaha
# 32639   First Owner   8.0  350.0  Royal Enfield
# 32640   First Owner   6.0  100.0           Hero
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32648 entries, 0 to 32647
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   32648 non-null  object
#  1   price       32648 non-null  float64
#  2   city        32648 non-null  object
#  3   kms_driven  32648 non-null  float64
#  4   owner       32648 non-null  object
#  5   age         32648 non-null  float64
#  6   power       32648 non-null  float64
#  7   brand       32648 non-null  object
# dtypes: float64(4), object(4)
# memory usage: 2.0+ MB

# %%
df.describe()
# Out:
#               price     kms_driven           age         power
# count  3.264800e+04   32648.000000  32648.000000  32648.000000
# mean   6.829542e+04   26344.625184      8.048211    213.511302
# std    9.071860e+04   22208.527695      4.031700    134.428868
# min    4.400000e+03       1.000000      1.000000    100.000000
# 25%    2.500000e+04   12000.000000      5.000000    150.000000
# 50%    4.300000e+04   20373.000000      7.000000    150.000000
# 75%    8.000000e+04   35000.000000     10.000000    220.000000
# max    1.900000e+06  750000.000000     63.000000   1800.000000

# %%
df.dtypes
# gives the datatype for the columns
# Out:
# bike_name      object
# price         float64
# city           object
# kms_driven    float64
# owner          object
# age           float64
# power         float64
# brand          object
# dtype: object

# %%
df.shape
# tells the shape of the dataset i.e 32648 :rows ,8:columns
# Out:
# (32648, 8)

# %%
print(df['bike_name'])
# to extract particular columns
# Out:
# 0          TVS Star City Plus Dual Tone 110cc
# 1                 Royal Enfield Classic 350cc
# 2                        Triumph Daytona 675R
# 3                        TVS Apache RTR 180cc
# 4        Yamaha FZ S V 2.0 150cc-Ltd. Edition
#                          ...
# 32643                  Hero Passion Pro 100cc
# 32644                    TVS Apache RTR 180cc
# 32645                Bajaj Avenger Street 220
# 32646               Hero Super Splendor 125cc
# 32647                      Bajaj Pulsar 150cc
# Name: bike_name, Length: 32648, dtype: object

# %%
df.columns
# Out:
# Index(['bike_name', 'price', 'city', 'kms_driven', 'owner', 'age', 'power',
#        'brand'],
#       dtype='object')

# %%
# df=df.drop(columns=['bike_name','city'])

# %%
brand_name_df=df["brand"]
brand_name_df
# to extract a specific column
# Out:
# 0                  TVS
# 1        Royal Enfield
# 2              Triumph
# 3                  TVS
# 4               Yamaha
#              ...
# 32643             Hero
# 32644              TVS
# 32645            Bajaj
# 32646             Hero
# 32647            Bajaj
# Name: brand, Length: 32648, dtype: object

# %%
brand_name_df.unique()
# unique values
# Out:
# array(['TVS', 'Royal Enfield', 'Triumph', 'Yamaha', 'Honda', 'Hero',
#        'Bajaj', 'Suzuki', 'Benelli', 'KTM', 'Mahindra', 'Kawasaki',
#        'Ducati', 'Hyosung', 'Harley-Davidson', 'Jawa', 'BMW', 'Indian',
#        'Rajdoot', 'LML', 'Yezdi', 'MV', 'Ideal'], dtype=object)

# %%
brand_name_df.nunique()
# number of unique columns
# Out:
# 23

# %%
bike_name_df=df['bike_name']
bike_name_df
# Out:
# 0          TVS Star City Plus Dual Tone 110cc
# 1                 Royal Enfield Classic 350cc
# 2                        Triumph Daytona 675R
# 3                        TVS Apache RTR 180cc
# 4        Yamaha FZ S V 2.0 150cc-Ltd. Edition
#                          ...
# 32643                  Hero Passion Pro 100cc
# 32644                    TVS Apache RTR 180cc
# 32645                Bajaj Avenger Street 220
# 32646               Hero Super Splendor 125cc
# 32647                      Bajaj Pulsar 150cc
# Name: bike_name, Length: 32648, dtype: object

# %%
bike_name_df.unique()
# Out:
# array(['TVS Star City Plus Dual Tone 110cc',
#        'Royal Enfield Classic 350cc', 'Triumph Daytona 675R',
#        'TVS Apache RTR 180cc', 'Yamaha FZ S V 2.0 150cc-Ltd. Edition',
#        'Yamaha FZs 150cc', 'Honda CB Hornet 160R  ABS DLX',
#        'Hero Splendor Plus Self Alloy 100cc',
#        'Royal Enfield Thunderbird X 350cc',
#        'Royal Enfield Classic Desert Storm 500cc',
#        'Yamaha YZF-R15 2.0 150cc', 'Yamaha FZ25 250cc',
#        'Bajaj Pulsar NS200', 'Bajaj Discover 100M', 'Bajaj Discover 125M',
#        'Bajaj Pulsar NS200 ABS', 'Bajaj Pulsar RS200 ABS',
#        'Suzuki Gixxer SF 150cc', 'Benelli 302R 300CC',
#        'Hero Splendor iSmart Plus IBS 110cc',
#        'Royal Enfield Classic Chrome 500cc', 'Yamaha FZ V 2.0 150cc',
#        'Hero Super Splendor 125cc', 'Honda CBF Stunner 125cc',
#        'Bajaj Pulsar 150cc', 'Honda X-Blade 160CC ABS',
#        'Bajaj Avenger 220cc', 'KTM RC 390cc', 'Honda CB Unicorn 150cc',
# ...

# %%
bike_name_df.nunique()
# Out:
# 471

# %%
df.iloc[0]
# df.iloc[] ka matlab "index location" hota hai.
# Out:
# bike_name     TVS Star City Plus Dual Tone 110cc
# price                                    35000.0
# city                                   Ahmedabad
# kms_driven                               17654.0
# owner                                First Owner
# age                                          3.0
# power                                      110.0
# brand                                        TVS
# Name: 0, dtype: object

# %%
df.iloc[-1]
# last column
# Out:
# bike_name     Bajaj Pulsar 150cc
# price                    22000.0
# city                        Pune
# kms_driven               60857.0
# owner                First Owner
# age                         13.0
# power                      150.0
# brand                      Bajaj
# Name: 32647, dtype: object

# %%
df.iloc[0:5]
# 0 se 5 columns tk
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
df.isnull()
# Out:
#        bike_name  price   city  kms_driven  owner    age  power  brand
# 0          False  False  False       False  False  False  False  False
# 1          False  False  False       False  False  False  False  False
# 2          False  False  False       False  False  False  False  False
# 3          False  False  False       False  False  False  False  False
# 4          False  False  False       False  False  False  False  False
# ...          ...    ...    ...         ...    ...    ...    ...    ...
# 32643      False  False  False       False  False  False  False  False
# 32644      False  False  False       False  False  False  False  False
# 32645      False  False  False       False  False  False  False  False
# 32646      False  False  False       False  False  False  False  False
# 32647      False  False  False       False  False  False  False  False
#
# [32648 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# bike_name     0
# price         0
# city          0
# kms_driven    0
# owner         0
# age           0
# power         0
# brand         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 25324

# %%
df.drop_duplicates(inplace=True)
# delete the duplicate value permanently

# %%
df.duplicated().sum()
# sum of all duplicate values
# Out:
# 0

# %%
df.dropna(inplace=True)
# delete all null values

# %%
df.isnull().sum()
# Out:
# bike_name     0
# price         0
# city          0
# kms_driven    0
# owner         0
# age           0
# power         0
# brand         0
# dtype: int64

# %%
df['bike_name'].duplicated().sum()
# duplicate value for specific column
# Out:
# 6853

# %%
df['brand'].duplicated().sum()
# Out:
# 7301

# %%
df['brand'].nunique()
# Out:
# 23

# %%
df.fillna(0)
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
# df['price'].fillna(df['price'].mean(),inplace=True)

# %%
# new_df=df['price'].mean()
# df.fillna(new_df)
# 2nd method

# %%
df.rename(columns={'kms_driven':'km_driven'},inplace=True)
# used to rename the columns

# %%
df.columns
# Out:
# Index(['bike_name', 'price', 'city', 'km_driven', 'owner', 'age', 'power',
#        'brand'],
#       dtype='object')

# %%
df['price'].head(10)
# Out:
# 0     35000.0
# 1    119900.0
# 2    600000.0
# 3     65000.0
# 4     80000.0
# 5     53499.0
# 6     85000.0
# 7     45000.0
# 8    145000.0
# 9     88000.0
# Name: price, dtype: float64

# %%
df.head(10)
# Out:
#                                   bike_name     price       city  km_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad    17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi    11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi      110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore    16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore    10000.0
# 5                          Yamaha FZs 150cc   53499.0      Delhi    25000.0
# 6             Honda CB Hornet 160R  ABS DLX   85000.0      Delhi     8200.0
# 7       Hero Splendor Plus Self Alloy 100cc   45000.0      Delhi    12645.0
# 8         Royal Enfield Thunderbird X 350cc  145000.0  Bangalore     9190.0
# 9  Royal Enfield Classic Desert Storm 500cc   88000.0      Delhi    19000.0
#
#           owner  age  power          brand
# 0   First Owner  3.0  110.0            TVS
# 1   First Owner  4.0  350.0  Royal Enfield
# ...

# %%
df.sort_index(ascending=False)
# Out:
#                                  bike_name     price       city  km_driven  \
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad     7127.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad    21300.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur     3430.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore    60000.0
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi    48587.0
# ...                                    ...       ...        ...        ...
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore    10000.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore    16329.0
# 2                     Triumph Daytona 675R  600000.0      Delhi      110.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi    11000.0
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad    17654.0
#
#             owner  age  power            brand
# ...

# %%
Char_column=df.select_dtypes(include='O')
# to extract the charcter columns where o="object"

# %%
Char_column
# Out:
#                                  bike_name       city        owner  \
# 0       TVS Star City Plus Dual Tone 110cc  Ahmedabad  First Owner
# 1              Royal Enfield Classic 350cc      Delhi  First Owner
# 2                     Triumph Daytona 675R      Delhi  First Owner
# 3                     TVS Apache RTR 180cc  Bangalore  First Owner
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition  Bangalore  First Owner
# ...                                    ...        ...          ...
# 9362             Hero Hunk Rear Disc 150cc      Delhi  First Owner
# 9369                   Bajaj Avenger 220cc  Bangalore  First Owner
# 9370        Harley-Davidson Street 750 ABS    Jodhpur  First Owner
# 9371                 Bajaj Dominar 400 ABS  Hyderabad  First Owner
# 9372              Bajaj Avenger Street 220  Hyderabad  First Owner
#
#                 brand
# 0                 TVS
# 1       Royal Enfield
# 2             Triumph
# 3                 TVS
# 4              Yamaha
# ...

# %%
num_column=df.select_dtypes(exclude='O')
# to extract only numerical column

# %%
num_column
# Out:
#          price  km_driven  age  power
# 0      35000.0    17654.0  3.0  110.0
# 1     119900.0    11000.0  4.0  350.0
# 2     600000.0      110.0  8.0  675.0
# 3      65000.0    16329.0  4.0  180.0
# 4      80000.0    10000.0  3.0  150.0
# ...        ...        ...  ...    ...
# 9362   25000.0    48587.0  8.0  150.0
# 9369   35000.0    60000.0  9.0  220.0
# 9370  450000.0     3430.0  4.0  750.0
# 9371  139000.0    21300.0  4.0  400.0
# 9372   80000.0     7127.0  5.0  220.0
#
# [7324 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7324 entries, 0 to 9372
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   bike_name  7324 non-null   object
#  1   price      7324 non-null   float64
#  2   city       7324 non-null   object
#  3   km_driven  7324 non-null   float64
#  4   owner      7324 non-null   object
#  5   age        7324 non-null   float64
#  6   power      7324 non-null   float64
#  7   brand      7324 non-null   object
# dtypes: float64(4), object(4)
# memory usage: 515.0+ KB

# %%
df=df.drop(columns=['city','bike_name'])

# %%
df.head()
# Out:
#       price  km_driven        owner  age  power          brand
# 0   35000.0    17654.0  First Owner  3.0  110.0            TVS
# 1  119900.0    11000.0  First Owner  4.0  350.0  Royal Enfield
# 2  600000.0      110.0  First Owner  8.0  675.0        Triumph
# 3   65000.0    16329.0  First Owner  4.0  180.0            TVS
# 4   80000.0    10000.0  First Owner  3.0  150.0         Yamaha

# %%
df['owner'].unique()
# Out:
# array(['First Owner', 'Second Owner', 'Third Owner',
#        'Fourth Owner Or More'], dtype=object)

# %%
owner_dic={'First Owner':1,'Second Owner':2,'Third Owner':3,'Fourth Owner Or More':4}

# %%
df['owner']=df['owner'].map(owner_dic)

# %%
df['owner'].unique()
# Out:
# array([1, 2, 3, 4], dtype=int64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7324 entries, 0 to 9372
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   price      7324 non-null   float64
#  1   km_driven  7324 non-null   float64
#  2   owner      7324 non-null   int64
#  3   age        7324 non-null   float64
#  4   power      7324 non-null   float64
#  5   brand      7324 non-null   object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 400.5+ KB

# %%
df['brand'].unique()
# Out:
# array(['TVS', 'Royal Enfield', 'Triumph', 'Yamaha', 'Honda', 'Hero',
#        'Bajaj', 'Suzuki', 'Benelli', 'KTM', 'Mahindra', 'Kawasaki',
#        'Ducati', 'Hyosung', 'Harley-Davidson', 'Jawa', 'BMW', 'Indian',
#        'Rajdoot', 'LML', 'Yezdi', 'MV', 'Ideal'], dtype=object)

# %%
# brand_dic={'TVS':1, 'Royal Enfield':2, 'Triumph':3, 'Yamaha':4, 'Honda':5, 'Hero':6,
#        'Bajaj':7, 'Suzuki':8, 'Benelli':9, 'KTM':10, 'Mahindra':11, 'Kawasaki':12,
#        'Ducati':13, 'Hyosung':14, 'Harley-Davidson':15, 'Jawa':16, 'BMW':17, 'Indian':18,
#        'Rajdoot':19, 'LML':20, 'Yezdi':21, 'MV':22, 'Ideal':23}

# %%
# df['brand']=df['brand'].map(brand_dic)

# %%
df['brand'].unique()
# Out:
# array(['TVS', 'Royal Enfield', 'Triumph', 'Yamaha', 'Honda', 'Hero',
#        'Bajaj', 'Suzuki', 'Benelli', 'KTM', 'Mahindra', 'Kawasaki',
#        'Ducati', 'Hyosung', 'Harley-Davidson', 'Jawa', 'BMW', 'Indian',
#        'Rajdoot', 'LML', 'Yezdi', 'MV', 'Ideal'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7324 entries, 0 to 9372
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   price      7324 non-null   float64
#  1   km_driven  7324 non-null   float64
#  2   owner      7324 non-null   int64
#  3   age        7324 non-null   float64
#  4   power      7324 non-null   float64
#  5   brand      7324 non-null   object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 400.5+ KB

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
le=LabelEncoder()
ohe=OneHotEncoder()

# %%
output=le.fit_transform(df['brand'])

# %%
output
# Out:
# array([19, 17, 20, ...,  4,  1,  1])

# %%
output.shape
# Out:
# (7324,)

# %%
df['brand']=output

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7324 entries, 0 to 9372
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   price      7324 non-null   float64
#  1   km_driven  7324 non-null   float64
#  2   owner      7324 non-null   int64
#  3   age        7324 non-null   float64
#  4   power      7324 non-null   float64
#  5   brand      7324 non-null   int32
# dtypes: float64(4), int32(1), int64(1)
# memory usage: 371.9 KB

# %%
df
# Out:
#          price  km_driven  owner  age  power  brand
# 0      35000.0    17654.0      1  3.0  110.0     19
# 1     119900.0    11000.0      1  4.0  350.0     17
# 2     600000.0      110.0      1  8.0  675.0     20
# 3      65000.0    16329.0      1  4.0  180.0     19
# 4      80000.0    10000.0      1  3.0  150.0     21
# ...        ...        ...    ...  ...    ...    ...
# 9362   25000.0    48587.0      1  8.0  150.0      5
# 9369   35000.0    60000.0      1  9.0  220.0      1
# 9370  450000.0     3430.0      1  4.0  750.0      4
# 9371  139000.0    21300.0      1  4.0  400.0      1
# 9372   80000.0     7127.0      1  5.0  220.0      1
#
# [7324 rows x 6 columns]

# %%
x=df.drop(columns=['price'])
x
# Out:
#       km_driven  owner  age  power  brand
# 0       17654.0      1  3.0  110.0     19
# 1       11000.0      1  4.0  350.0     17
# 2         110.0      1  8.0  675.0     20
# 3       16329.0      1  4.0  180.0     19
# 4       10000.0      1  3.0  150.0     21
# ...         ...    ...  ...    ...    ...
# 9362    48587.0      1  8.0  150.0      5
# 9369    60000.0      1  9.0  220.0      1
# 9370     3430.0      1  4.0  750.0      4
# 9371    21300.0      1  4.0  400.0      1
# 9372     7127.0      1  5.0  220.0      1
#
# [7324 rows x 5 columns]

# %%
x.shape
# Out:
# (7324, 5)

# %%
y=df[['price']]
y
# Out:
#          price
# 0      35000.0
# 1     119900.0
# 2     600000.0
# 3      65000.0
# 4      80000.0
# ...        ...
# 9362   25000.0
# 9369   35000.0
# 9370  450000.0
# 9371  139000.0
# 9372   80000.0
#
# [7324 rows x 1 columns]

# %%
# to train the model
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((5859, 5), (1465, 5), (5859, 1), (1465, 1))

# %%
x_train.head()
# Out:
#       km_driven  owner   age  power  brand
# 5789    68857.0      1  15.0  110.0     19
# 3451     5740.0      1   6.0  500.0     17
# 735     28329.0      1   6.0  110.0      5
# 7533    42966.0      1   7.0  150.0     21
# 8461     8000.0      1   5.0  500.0     17

# %%
x_test.head()
# Out:
#       km_driven  owner   age  power  brand
# 4909    22500.0      1   6.0  350.0     17
# 1942     3198.0      1   5.0  500.0     17
# 5763    15000.0      1   6.0  220.0      1
# 4800    27000.0      1  12.0  150.0     21
# 7614    16764.0      1   9.0  100.0      5

# %%
y_train.head()
# Out:
#          price
# 5789   18000.0
# 3451  140000.0
# 735    32000.0
# 7533   40000.0
# 8461  160000.0

# %%
y_test.head()
# Out:
#          price
# 4909   88400.0
# 1942  102850.0
# 5763   67000.0
# 4800   30000.0
# 7614   20000.0

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print("training_score:",lr.score(x_train,y_train))
# Out:
# training_score: 0.6583186303624649

# %%
print("testing_score:",lr.score(x_test,y_test))
# Out:
# testing_score: 0.7175947383086565

# %%
# prediction part
pred=lr.predict(x_test)
pred
# Out:
# array([[150683.50273601],
#        [246408.76411648],
#        [ 94949.23656378],
#        ...,
#        [ 37079.00523583],
#        [238205.04024506],
#        [ 36702.67235501]])

# %%
pred
# Out:
# array([[150683.50273601],
#        [246408.76411648],
#        [ 94949.23656378],
#        ...,
#        [ 37079.00523583],
#        [238205.04024506],
#        [ 36702.67235501]])

# %%
x_test.shape
# Out:
# (1465, 5)

# %%
y_test['pred']=pred.ravel()

# %%
y_test
# Out:
#          price           pred
# 4909   88400.0  150683.502736
# 1942  102850.0  246408.764116
# 5763   67000.0   94949.236564
# 4800   30000.0    2790.775522
# 7614   20000.0    6456.787056
# ...        ...            ...
# 5653  395000.0  411532.041280
# 609   140000.0  102647.279228
# 4211   54500.0   37079.005236
# 6379  114000.0  238205.040245
# 647    36000.0   36702.672355
#
# [1465 rows x 2 columns]

# %%
pred=(pred>0.5).astype(int).ravel()

# %%
y_test=(y_test>0.5).astype(int)

# %% [markdown]
# Loss function
# * MSE
# * MAE
# * RMSE
# * HUBER LOSS

# %%
# import joblib as jb
# jb.dump(model,'bike.pkl')
# print("saved successfullyyyyyyyyy")
# to save the model and to load the  model data

# %%
# mean square error is not used when we have outliers in the data,to deal with this error,we have mean absolute error:
# for regression problems:
# 1.Mean square error
# 2 .Mean Absolute Error
# 3.Root mean square error

# Hybrid Loss Function (Huber Loss)
# Huber Loss MAE aur MSE ka combination hai.
# Chhoti errors ke liye MSE ka use karta hai (smooth optimization ke liye).
# Badi errors ke liye MAE ka use karta hai (outliers ke effect ko reduce karta hai).
# Ek delta (δ) threshold define hota hai, jiske baad MAE apply hota hai.

# %%
pred.shape,y_test.shape
# Out:
# ((1465,), (1465, 2))

# %% [markdown]
# # MSE

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
print("mse:",mean_squared_error(y_test['price'],pred))
# Out:
# mse: 0.06075085324232082

# %% [markdown]
# # MAE

# %%
from sklearn.metrics import mean_absolute_error
y=mean_absolute_error(y_test['price'],pred)
print("mae:",mean_absolute_error(y_test['price'],pred))
# Out:
# mae: 0.06075085324232082

# %% [markdown]
# # RMSE

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
x=mean_squared_error(y_test['price'],pred)
print("rmse:",x**0.5)
# Out:
# rmse: 0.24647688176038096

# %% [markdown]
# # Huber loss

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
print("huber_loss:",x+y)
# Out:
# huber_loss: 0.12150170648464163

# %% [markdown]
# * FP:TYPE 1 ERROR
#
# * FN:TYPE 2 ERROR

# %% [markdown]
# ### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix,f1_score,precision_score,recall_score
cm=confusion_matrix(y_test['price'],pred)
cm
# Out:
# array([[   0,    0],
#        [  89, 1376]], dtype=int64)

# %%
f1_score=f1_score(y_test['price'],pred)
f1_score
# Out:
# 0.9686730024639212

# %%
precision_score=precision_score(y_test['price'],pred)
precision_score
# Out:
# 1.0

# %%
recall_score=recall_score(y_test['price'],pred)
recall_score
# Out:
# 0.9392491467576792

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.heatmap(cm,annot=True,cmap='Blues',fmt='d')
plt.xlabel('predicted')
plt.ylabel('original')
plt.show()
